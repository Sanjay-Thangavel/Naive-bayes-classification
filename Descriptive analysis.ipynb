# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

datum = pd.read_csv("Inc_Exp_Data.csv")

datum.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
datum.shape
# Out:
# (50, 7)

# %%
datum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
datum.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
datum.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
datum.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
datum['Highest_Qualified_Member'].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %%
print(datum.Highest_Qualified_Member.unique())
# Out:
# ['Under-Graduate' 'Illiterate' 'Graduate' 'Post-Graduate' 'Professional']

# %%
#1D Scatter points 

datum_Under_Graduate = datum.loc[datum["Highest_Qualified_Member"] ==  "Under-Graduate"];
datum_Illiterate =  datum.loc[ datum["Highest_Qualified_Member"] == "Illiterate"];
datum_Graduate =  datum.loc[ datum["Highest_Qualified_Member"] == "Graduate"];

datum_Post_Graduate =  datum.loc[ datum["Highest_Qualified_Member"] == "Post-Graduate"];

datum_Professional =  datum.loc[ datum["Highest_Qualified_Member"] == "Professional"];

# zero_like gives same shape filled with zero  
# print("Setso :\n",iris_setso)
# print("virginica \n :", iris_virginica)

plt.plot(datum_Under_Graduate["Annual_HH_Income"], np.zeros_like(datum_Under_Graduate["Annual_HH_Income"]),"o")

plt.plot(datum_Illiterate["Annual_HH_Income"], np.zeros_like(datum_Illiterate["Annual_HH_Income"]),"o")

plt.plot(datum_Graduate["Annual_HH_Income"], np.zeros_like(datum_Graduate["Annual_HH_Income"]),"o")

plt.plot(datum_Post_Graduate["Annual_HH_Income"], np.zeros_like(datum_Post_Graduate["Annual_HH_Income"]),"o")

plt.plot(datum_Professional["Annual_HH_Income"], np.zeros_like(datum_Professional["Annual_HH_Income"]),"o")


plt.grid()

plt.show()

# %%
#2D Sctter points
iris.plot(kind="scatter",x="Highest_Qualified_Member",y="Annual_HH_Income")
plt.show()

# %%
datum
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
import seaborn as sns
sns.pairplot(datum.drop(['No_of_Earning_Members'], axis = 1), hue='Annual_HH_Income', height=2)

# %%
sns.heatmap(iris.corr(method='pearson').drop( ['No_of_Earning_Members'], axis=1),
annot = True);
plt.show()

# %%
sns.boxplot(x='Annual_HH_Income',data =iris)
# Out:
# <AxesSubplot:xlabel='Annual_HH_Income'>
